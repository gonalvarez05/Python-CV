# %% [markdown]
# ## Resume in python

# %%
# Text Variables
Header = '>>>This resume was generated entirely in Python. For full sourcecode, view my github.'
Name = 'GONZALO ÁLVAREZ MUÑOZ'
Title = 'Business + Data Science & Analytics'
Contact = 'Madrid, Spain\n+34 646877437\ngonalvarez05@gmail.com\nlinkedin.com/in/gonzalo-alvarez-16652918a/\ngithub.com/gonalvarez05'
ProjectsHeader = 'PROJECTS'
ProjectOneTitle = 'Data Jobs in Europe'
ProjectOneDesc = '- Create a Data Pipeline extracting data from a database, API and a Url.\n- Clean the data with pandas library and analyse it.\n- Make a report with data jobs in Europe groupedby countries\n and other demographic variables.        '
ProjectTwoTitle = 'Exploratory Analysis of Diamonds '
ProjectTwoDesc = '- Clean and combine data using pandas library in Python.\n- Used statistics and visualization to determine correlations for future study.'

WorkHeader = 'EXPERIENCE'
WorkOneTitle = 'Barrabés.biz / Strategic Innovation Consultor'
WorkOneTime = '06/2019-08/2019'
WorkOneDesc = '- Define, design and execute digital strategic projects with\n  public and private enterprises.\n- Elaborate products with emerging technologies such as\n  IoT, Big Data and Artificial Inteligence.'
WorkTwoTitle = 'Santander Bank / Commercial in a Bank Branch'
WorkTwoTime = '07/2018-09/2019'
WorkTwoDesc ='- Direct contact with clients.\n- Had the opportunity to acquire knowledge of a bank structure,\n bank transactions, sources of funding and a problem-solver ability.'


EduHeader = 'EDUCATION'
EduOneTitle = 'Ironhack, Bootcamp in Data Science & Analytics'
EduOneTime = '2020-present'
EduOneDesc= '- Data Analysis using Python (Pandas, Numpy) & MySQL.\n- Data Visualization (Tableau, Plotly, Seaborn).\n- Build, Evaluate & Deploy Machine Learning Models and Pipelines.\n- Inferential Statistics in Python & Business Inteligence.\n- Data Wrangling, Data Cleaning, API & Web Scraping.'
EduTwoTitle = 'CUNEF, Bachelor of Business Administration'
EduTwoTime = '2016-2020'
EduThreeTitle = 'Finance Summer Program at Penn State University \n (Pennsylvania, EEUU)'
EduThreeTime = '2015'
EduFourTitle = 'Caldicott Boarding School (London)'
EduFourTime = '2010-2011'
EduFiveTitle = 'Colegio Nuestra Señora del Recuerdo (Madrid, Spain)'
EduFiveTime = 'Until 2016'


LanguagesHeader= 'LANGUAGES'
Languages= '- Spanish: Native\n- English: Proficiency (Writing and Speaking)'

SkillsHeader = 'Hard Skills'
SkillsDesc = '- Python\n- Pandas\n- NumPy\n- Scikit-learn\n- Data Cleaning\n- Data Manipulation\n- Data Visualization\n- Data Pipelines\n- Command Line\n- Git and Version Control\n- SQL\n- APIs\n- Web Scraping \n- Probability/Statistics\n- Excel'
ExtrasTitle = 'Soft Skills'
ExtrasDesc = '- Communication Skills\n- Entrepeneurial Mindset\n- Problem-Solving Skills\n- Team Player \n - Ability to take initiative '
CodeTitle = 'View Github'

# Setting style for bar graphs
import matplotlib.pyplot as plt
# %matplotlib inline

# set font

plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'
fig, ax = plt.subplots(figsize=(8.5, 11))

# Decorative Lines

ax.axvline(x=.5, ymin=0, ymax=1, color='#007ACC', alpha=0.0, linewidth=50)
plt.axvline(x=.99, color='#000000', alpha=0.5, linewidth=300)
plt.axhline(y=.88, xmin=0, xmax=1, color='#ffffff', linewidth=3)

# set background color

ax.set_facecolor('white')
# remove axes

plt.axis('off')
# add text
plt.annotate(Header, (.02,.98), weight='regular', fontsize=8, alpha=.75)
plt.annotate(Name, (.02,.94), weight='bold', fontsize=20)
plt.annotate(Title, (.02,.91), weight='regular', fontsize=14)
plt.annotate(Contact, (.7,.906), weight='regular', fontsize=8, color='#ffffff')

plt.annotate(ProjectsHeader, (.02,.875), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(ProjectOneTitle, (.02,.85), weight='bold', fontsize=10)
plt.annotate(ProjectOneDesc, (.04,.78), weight='regular', fontsize=9)
plt.annotate(ProjectTwoTitle, (.02,.745), weight='bold', fontsize=10)
plt.annotate(ProjectTwoDesc, (.04,.71), weight='regular', fontsize=9)

plt.annotate(WorkHeader, (.02,.675), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(WorkOneTitle, (.02,.65), weight='bold', fontsize=10)
plt.annotate(WorkOneTime,(.02,.635), weight='regular', fontsize=9, alpha=.6)
plt.annotate(WorkOneDesc, (.04,.57), weight='regular', fontsize=9)
plt.annotate(WorkTwoTitle, (.02,.545), weight='bold', fontsize=10)
plt.annotate(WorkTwoTime, (.02,.53), weight='regular', fontsize=9, alpha=.6)
plt.annotate(WorkTwoDesc, (.04,.48), weight='regular', fontsize=9)

plt.annotate(EduHeader, (.02,.439), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(EduOneTitle, (.02,.42), weight='bold', fontsize=10)
plt.annotate(EduOneTime, (.02,.405), weight='regular', fontsize=9, alpha=.6)
plt.annotate(EduOneDesc, (.04,.32), weight='regular', fontsize=9)
plt.annotate(EduTwoTitle, (.02,.29), weight='bold', fontsize=10)
plt.annotate(EduTwoTime, (.02,.275), weight='regular', fontsize=9, alpha=.6)
plt.annotate(EduThreeTitle, (.02,.23), weight='bold', fontsize=10)
plt.annotate(EduThreeTime, (.02,.215), weight='regular', fontsize=9, alpha=.6)
plt.annotate(EduFourTitle, (.02,.19), weight='bold', fontsize=10)
plt.annotate(EduFourTime, (.02,.175), weight='regular', fontsize=9, alpha=.6)
plt.annotate(EduFiveTitle, (.02,.145), weight='bold', fontsize=10)
plt.annotate(EduFiveTime, (.02,.125), weight='regular', fontsize=9, alpha=.6)
plt.annotate(LanguagesHeader, (.02,.09), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(Languages, (.04,.055), weight='regular', fontsize=9)



plt.annotate(SkillsHeader, (.7,.85), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(SkillsDesc, (.7,.555), weight='regular', fontsize=10, color='#ffffff')
plt.annotate(ExtrasTitle, (.7,.50), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(ExtrasDesc, (.7,.39), weight='regular', fontsize=10, color='#ffffff')
plt.annotate(CodeTitle, (.7,.25), weight='bold', fontsize=10, color='#ffffff')

#add qr code

from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import matplotlib.image as mpimg
arr_code = mpimg.imread('sample.png')
imagebox = OffsetImage(arr_code, zoom=0.20)
ab = AnnotationBbox(imagebox, (0.83, 0.14))
ax.add_artist(ab)
plt.savefig('gonzaloalvarezCV.pdf', dpi=300, bbox_inches='tight')

# %%
import qrcode
from PIL import Image

# %%
img=qrcode.make('https://github.com/gonalvarez05/Python-Resume')

# %%
qr = qrcode.QRCode(
    version=1,
    error_correction=qrcode.constants.ERROR_CORRECT_H,
    box_size=10,
    border=4,
)

# %%
qr.add_data('https://github.com/gonalvarez05')
qr.make(fit=True)
img = qr.make_image(fill_color="black", back_color="white").convert('RGB')

# %%
img.save('sample.png')
